# %%
# Initialize Otter
import otter
grader = otter.Notebook("ps1.ipynb")

# %%
# Initialize Otter
import otter
grader = otter.Notebook("Assignment1.ipynb")

# %% [markdown]
# ## Environment setup
# For this assingment you have two options; just [download Anaconda](https://www.anaconda.com/download/) and install otter grader as instructed in the first code cell below OR setup Docker as given below

# %% [markdown]
# ## Docker setup
#
# If you are using Windows operating system, you are encouraged to install Docker and download the necessary image instead of directly downloading the necessary software on your operating system as it is much easier to work with Docker container.
#
# To use docker follow the instructions below
# * Visit https://docs.docker.com/desktop/ and click on Install Docker Desktop that is meant for your Operating System and follow through the instructions.
# * Open the Console (a.k.a. Terminal) application on your computer
# * Visit https://hub.docker.com/repository/docker/jravi123/mbcc-anaconda/general and follow the instructions to pull jravi123/mbcc-anaconda:latest image by running the commands from the Console.
#
# **Note:** If you execute the 'run' command on your image more than once, you will spawn multiple Jupyter Lab servers and there by will notice the second time around it fails to start Jupyter Lab due to port conflict (port 8888 is already occupied by the first server). You can manage these instances by opening the 'Container/Apps' tab of your Docker desktop Dashboard.

# %% [markdown]
# ### EDA on chronic diseases
# This data corresponds to the open dataset provided by U.S. Department of Health & Human Services
#
# https://catalog.data.gov/dataset/u-s-chronic-disease-indicators-cdi
#
# To receive full points you should have the following:
# * Plots should have legible labels for the x and y-axis and a title. (-0.5 points otherwise)
# * Every plot should be explained with a markdown section below it. (-0.5 points otherwise)
# * Should have a final conclusion explaining insights as found by you or hypothesis if any. (-1 point)

# %% [markdown]
# The first cell imports the autograder package that we are using to autograde your assignments. If running the above cell generates an error, it means that you do not have this package installed. Students who are using Docker will not have this issue as it is already installed.
# Others can install it by uncommenting and running the following command:

# %%
# %pip install otter-grader
# Out:
# Requirement already satisfied: otter-grader in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (5.2.2)
# Requirement already satisfied: dill in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (0.3.6)
# Requirement already satisfied: jinja2 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (3.1.2)
# Requirement already satisfied: nbformat in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (5.9.2)
# Requirement already satisfied: pandas in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (2.0.3)
# Requirement already satisfied: PyYAML in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (6.0)
# Requirement already satisfied: python-on-whales in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (0.65.0)
# Requirement already satisfied: requests in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (2.31.0)
# Requirement already satisfied: wrapt in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (1.14.1)
# Requirement already satisfied: jupytext in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (1.15.2)
# Requirement already satisfied: click in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (8.0.4)
# Requirement already satisfied: fica>=0.3.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (0.3.1)
# Requirement already satisfied: ipython in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (8.15.0)
# Requirement already satisfied: astunparse in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (1.6.3)
# Requirement already satisfied: ipywidgets in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (8.0.4)
# Requirement already satisfied: ipylab in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (1.0.0)
# Requirement already satisfied: nbconvert in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from otter-grader) (6.5.4)
# Requirement already satisfied: docutils in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from fica>=0.3.0->otter-grader) (0.18.1)
# Requirement already satisfied: sphinx in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from fica>=0.3.0->otter-grader) (5.0.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from astunparse->otter-grader) (0.38.4)
# Requirement already satisfied: six<2.0,>=1.6.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from astunparse->otter-grader) (1.16.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipywidgets->otter-grader) (6.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipywidgets->otter-grader) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipywidgets->otter-grader) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipywidgets->otter-grader) (3.0.5)
# Requirement already satisfied: backcall in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipython->otter-grader) (0.2.0)
# Requirement already satisfied: decorator in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipython->otter-grader) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipython->otter-grader) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipython->otter-grader) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipython->otter-grader) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipython->otter-grader) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipython->otter-grader) (2.15.1)
# Requirement already satisfied: stack-data in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipython->otter-grader) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipython->otter-grader) (4.8.0)
# Requirement already satisfied: appnope in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipython->otter-grader) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from jinja2->otter-grader) (2.1.1)
# Requirement already satisfied: toml in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from jupytext->otter-grader) (0.10.2)
# Requirement already satisfied: markdown-it-py>=1.0.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from jupytext->otter-grader) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from jupytext->otter-grader) (0.3.0)
# Requirement already satisfied: lxml in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (4.12.2)
# Requirement already satisfied: bleach in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (4.1.0)
# Requirement already satisfied: defusedxml in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (0.4)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (5.3.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (0.5.13)
# Requirement already satisfied: packaging in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (23.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbconvert->otter-grader) (1.2.1)
# Requirement already satisfied: fastjsonschema in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbformat->otter-grader) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from nbformat->otter-grader) (4.17.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from pandas->otter-grader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from pandas->otter-grader) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from pandas->otter-grader) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from pandas->otter-grader) (1.24.3)
# Requirement already satisfied: pydantic!=2.0.*,<3,>=1.5 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from python-on-whales->otter-grader) (1.10.8)
# Requirement already satisfied: tqdm in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from python-on-whales->otter-grader) (4.65.0)
# Requirement already satisfied: typer>=0.4.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from python-on-whales->otter-grader) (0.9.0)
# Requirement already satisfied: typing-extensions in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from python-on-whales->otter-grader) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from requests->otter-grader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from requests->otter-grader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from requests->otter-grader) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from requests->otter-grader) (2023.7.22)
# Requirement already satisfied: comm>=0.1.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->otter-grader) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->otter-grader) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->otter-grader) (7.4.9)
# Requirement already satisfied: nest-asyncio in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->otter-grader) (1.5.6)
# Requirement already satisfied: psutil in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->otter-grader) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->otter-grader) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->otter-grader) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython->otter-grader) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->otter-grader) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->otter-grader) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from jupyter-core>=4.7->nbconvert->otter-grader) (3.10.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=1.0.0->jupytext->otter-grader) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython->otter-grader) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->otter-grader) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->otter-grader) (2.4)
# Requirement already satisfied: webencodings in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from bleach->nbconvert->otter-grader) (0.5.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from sphinx->fica>=0.3.0->otter-grader) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from sphinx->fica>=0.3.0->otter-grader) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from sphinx->fica>=0.3.0->otter-grader) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from sphinx->fica>=0.3.0->otter-grader) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from sphinx->fica>=0.3.0->otter-grader) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from sphinx->fica>=0.3.0->otter-grader) (1.0.3)
# Requirement already satisfied: snowballstemmer>=1.1 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from sphinx->fica>=0.3.0->otter-grader) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from sphinx->fica>=0.3.0->otter-grader) (2.11.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from sphinx->fica>=0.3.0->otter-grader) (0.7.12)
# Requirement already satisfied: imagesize in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from sphinx->fica>=0.3.0->otter-grader) (1.4.1)
# Requirement already satisfied: executing in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->otter-grader) (0.8.3)
# Requirement already satisfied: asttokens in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->otter-grader) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->otter-grader) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# You only need to install this package once. Restart your kernel after installing and verify that the `otter` package loads.

# %% [markdown]
# ## Autograded questions
# You should fill in the answers where indicated, and then submit this notebook to Gradescope for grading as detailed in the assignment instructions.

# %% [markdown]
# ### Question 1
# Load the dataset from this URL into a dataframe variable named `df`
#
# URL: https://storage.googleapis.com/assignment-data/U.S._Chronic_Disease_Indicators__CDI_.csv

# %%
import pandas as pd
URL = 'https://storage.googleapis.com/assignment-data/U.S._Chronic_Disease_Indicators__CDI_.csv'
df = pd.read_csv(URL, low_memory=False)

# %%
df
# Out:
#          YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0             2010     2010           OR          Oregon       NVSS
# 1             2019     2019           AZ         Arizona      YRBSS
# 2             2019     2019           OH            Ohio      YRBSS
# 3             2019     2019           US   United States      YRBSS
# 4             2015     2015           VI  Virgin Islands      YRBSS
# ...            ...      ...          ...             ...        ...
# 1185671       2020     2020           WY         Wyoming      BRFSS
# 1185672       2020     2020           WY         Wyoming      BRFSS
# 1185673       2017     2017           IA            Iowa      BRFSS
# 1185674       2020     2020           WY         Wyoming      BRFSS
# 1185675       2019     2019           RI    Rhode Island      BRFSS
#
#                           Topic  \
# 0        Cardiovascular Disease
# 1                       Alcohol
# 2                       Alcohol
# 3                       Alcohol
# 4                       Alcohol
# ...                         ...
# 1185671                Diabetes
# 1185672            Older Adults
# 1185673               Arthritis
# 1185674                Diabetes
# 1185675               Arthritis
#
#                                                   Question  Response  \
# 0                             Mortality from heart failure       NaN
# 1                                  Alcohol use among youth       NaN
# 2                                  Alcohol use among youth       NaN
# 3                                  Alcohol use among youth       NaN
# 4                                  Alcohol use among youth       NaN
# ...                                                    ...       ...
# 1185671  Dilated eye examination among adults aged >= 1...       NaN
# 1185672  Proportion of older adults aged >= 65 years wh...       NaN
# 1185673  Activity limitation due to arthritis among adu...       NaN
# 1185674   Diabetes prevalence among women aged 18-44 years       NaN
# 1185675  Activity limitation due to arthritis among adu...       NaN
#
#         DataValueUnit            DataValueType  ... LocationID  TopicID  \
# 0                 NaN                   Number  ...         41      CVD
# 1                   %         Crude Prevalence  ...          4      ALC
# 2                   %         Crude Prevalence  ...         39      ALC
# 3                   %         Crude Prevalence  ...         59      ALC
# 4                   %         Crude Prevalence  ...         78      ALC
# ...               ...                      ...  ...        ...      ...
# 1185671             %  Age-adjusted Prevalence  ...         56      DIA
# 1185672             %         Crude Prevalence  ...         56      OLD
# 1185673             %  Age-adjusted Prevalence  ...         19      ART
# 1185674             %         Crude Prevalence  ...         56      DIA
# 1185675             %         Crude Prevalence  ...         44      ART
#
#         QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0           CVD1_4            NMBR                       RACE
# 1           ALC1_1         CRDPREV                     GENDER
# 2           ALC1_1         CRDPREV                     GENDER
# 3           ALC1_1         CRDPREV                       RACE
# 4           ALC1_1         CRDPREV                     GENDER
# ...            ...             ...                        ...
# 1185671     DIA7_0      AGEADJPREV                       RACE
# 1185672     OLD3_1         CRDPREV                       RACE
# 1185673     ART2_1      AGEADJPREV                       RACE
# 1185674     DIA2_2         CRDPREV                       RACE
# 1185675     ART2_1         CRDPREV                    OVERALL
#
#          StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0                     AIAN                       NaN               NaN
# 1                     GENF                       NaN               NaN
# 2                     GENM                       NaN               NaN
# 3                      ASN                       NaN               NaN
# 4                     GENM                       NaN               NaN
# ...                    ...                       ...               ...
# 1185671                WHT                       NaN               NaN
# 1185672                WHT                       NaN               NaN
# 1185673                HIS                       NaN               NaN
# 1185674                HIS                       NaN               NaN
# 1185675                OVR                       NaN               NaN
#
#          StratificationCategoryID3  StratificationID3
# 0                              NaN                NaN
# 1                              NaN                NaN
# 2                              NaN                NaN
# 3                              NaN                NaN
# 4                              NaN                NaN
# ...                            ...                ...
# 1185671                        NaN                NaN
# 1185672                        NaN                NaN
# 1185673                        NaN                NaN
# 1185674                        NaN                NaN
# 1185675                        NaN                NaN
#
# [1185676 rows x 34 columns]

# %%
grader.check("q1")
# Out:
# q1 results: All test cases passed!

# %% [markdown]
# ### Question 2
# There are many columns that have only null values. Drop those columns and ensure that the existing `df` variable represents the dataframe with dropped columns. Then get the columns names of this `df` and place it in the `cols` variable using a suitable expression

# %%
df = pd.read_csv(URL, low_memory=False)

df=df.dropna(axis=1,how='all')

cols = df.columns

# %%
grader.check("q2")
# Out:
# q2 results: All test cases passed!

# %% [markdown]
# ### Question 3
# What do you notice with the data? Write at least four cleaning steps you would take on this dataset

# %%
## Your solution here
#formatting the data 
import pandas as pd

#df = pd.read_csv(URL, low_memory=False)

# Convert 'Year Start' to datetime format
df['YearStart'] = pd.to_datetime(df['YearStart'])
# Convert 'Question' to lowercase
df['Question'] = df['Question'].str.lower()

#removing null values
df=df.dropna(axis=1,how='all')

cols = df.columns

#remove duplicates 


duplicate_rows = df[df.duplicated()]

df.drop_duplicates(inplace=True)
print(f"Number of rows in the cleaned dataset: {len(df)}")





#Handling missing values


col_missing_values = df.columns[df.isnull().sum() > 0]

rows_missing_values = df[df.isnull().any(axis=1)]
# Out:
# Number of rows in the cleaned dataset: 1185676

# %% [markdown]
# ### Question 4
# How many unique QuestionID's are there in this dataset? Get that number and place it in the variable given below using a suitable expression.

# %%
import pandas as pd

unique_question_ids = df['QuestionID'].unique()
num_unique_question_ids = len(unique_question_ids)
unique_question_id_count = num_unique_question_ids
print(unique_question_id_count)
# Out:
# 203

# %%
grader.check("q4")
# Out:
# q4 results: All test cases passed!

# %% [markdown]
# ### Question 5
#
# Select all the records that have the value `Cardiovascular Disease` in the Topic column and plot a bar chart that shows how many times each Question appears in this dataset (frequence distribution of the Question column). Please explain the findings in a new markdown section

# %%
import matplotlib.pyplot as plt
import pandas as pd

URL = 'https://storage.googleapis.com/assignment-data/U.S._Chronic_Disease_Indicators__CDI_.csv'
df = pd.read_csv(URL, low_memory=False)
# Select all records that have the value "Cardiovascular Disease" in the Topic column
df_filtered = df[df['Topic'] == 'Cardiovascular Disease']

# Get the frequency distribution of the Question column
question_counts = df_filtered['Question'].value_counts()

# Sort the question counts in descending order
question_counts = question_counts.sort_values(ascending=False)

# Get the bar names
bar_names = question_counts.index.astype(str).to_list()

# Rotate the x axis labels if the number of bars and the max_name_length are large
if len(bar_names) * max(len(name) for name in bar_names) >= 50:
    plt.xticks(rotation=90, fontsize=6)

# Remove extra bars because car chart can not show more than 30 bars properly
if len(bar_names) > 30:
    question_counts = question_counts.head(30)
    print('Bar plot has been truncated to show only 30 bars')

# Create a bar chart of the question counts
plt.bar(question_counts.index, question_counts.values)
plt.xlabel('Question')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Questions in Cardiovascular Disease Topic')
plt.show()

# %%
The majorfinding of this analysis is the major risk factors of the cardio vascular disease.
This can be used to develop educational materials and programs to help people learn more about cardiovascular disease and its risk factors. 
For example, a public health campaign could be developed to educate people about the major risk factors for cardiovascular disease and how to reduce their risk.

b)Another findings is that the risk factors of chronic diseases. 
The dataset contains data on a variety of risk factors for chronic diseases, such as smoking, obesity, and physical inactivity. 
By analyzing the most common risk factors for chronic diseases, we can develop strategies to reduce the risk of chronic diseases in the population.

# %% [markdown]
# ### Question 6
# Now, we will get some subset of records and look at the data from multiple facets. Get only those records that are
# * having `Cardiovascular Disease` as the value in the `Topic` column
# * having `MI` as the value in the `LocationAbbr` column
# * `Stratification1` column should contain only 'Male' and 'Female'
# * `DataValueTypeID` should have only `CRDPREV` as the value
#
# Then plot one figure that has many subplots that shows the `YearStart` values and its corresponding `DataValue` for the respective year shown as a trend line. The figure should consist of multiple subplots based on two facets; one on Gender 'Male' or 'Female' and on QuestionID's.
#
# Hint: you can select to show the Male or Female as two columns and one row for each QuestionID. You may use sns Facetgrid:
# https://seaborn.pydata.org/generated/seaborn.FacetGrid.html
#
# To get full points, you need to explain your insights after plotting this chart

# %%
# %pip install seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Read the U.S. Chronic Disease Indicators (CDI) dataset
df = pd.read_csv(URL,low_memory=False)

# Filter the dataset to only include the desired records
df_filtered = df[(df["Topic"] == "Cardiovascular Disease") & (df["LocationAbbr"] == "MI") & (df["Stratification1"].isin(["Male", "Female"])) & (df["DataValueTypeID"] == "CRDPREV")]

# Create a FacetGrid object with two facets: Gender and QuestionID
g = sns.FacetGrid(df_filtered, col="Stratification1", row="QuestionID", sharex=False, sharey=False)

# Map the line plot function to each facet
g.map_dataframe(sns.lineplot, x="YearStart", y="DataValue", size=5, linewidth=2)

# Set the axis labels and titles
g.set_axis_labels("YearStart", "DataValue")
g.set_titles("Question {row_var} - {col_var}")

# Show the plot
plt.show()
# Out:
# /Users/SwathiB/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning:
#
# The figure layout has changed to tight

# %%
Insights :
The chart of trend lines of DataValue vs YearStart by gender and QuestionID for cardiovascular disease in Michigan shows that the DataValue for each QuestionID is generally increasing over time for both males and females. However, there are some notable differences between the two genders.
The trend of DataValue over YearStart is different for males and females for most of the QuestionIDs.
For most of the QuestionIDs, the DataValue is higher for females than for males.
The trend of DataValue over YearStart is increasing for most of the QuestionIDs for both males and females.

# %% [markdown]
# ### Question 7
# Answer any other questions that might have to come to your mind after working on this dataset for this long.
# You have to show at least 3 different charts (for e.g, one line, one bar chart and one scatter). Explain your findings after every chart

# %%
# your answer here

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the U.S. Chronic Disease Indicators (CDI) dataset
df = pd.read_csv(URL,low_memory=False)

# Extract the prevalence data
Number = df['DataValueType']

 # Plot the trendline
plt.plot(Number, label='Number')

 # Set the axis labels and title
plt.xlabel('Data Value')
plt.ylabel('Number(%)')
plt.title('Trend in Number of Alcohol in Michigan')

 # Add a legend
plt.legend()

 
# Show the plot
plt.show()

# %%
#Bar plot

df_filtered = df[df['Topic'] == 'Alcohol']

 


location = df_filtered['LocationAbbr']
Alcohol = df_filtered['Question']

 


Alcohol_count = df_filtered.groupby('LocationAbbr')['Question'].count()

 

Alcohol, location = zip(*sorted(zip(Alcohol, location), key=lambda x: x[1], reverse=True))

 

#  bar chart
plt.bar(Alcohol, location)

 


plt.xlabel('Alcohol')
plt.ylabel('Number of cases')
plt.title('Number of Alcohol cases by region')

 

# Rotating the x-axis labels to prevent overlapping
plt.xticks(rotation=100,fontsize =8)

plt.yticks(rotation =100,fontsize = 8)


 

# Show the plot
plt.show()

# %%
#Scatter plot
import pandas as pd
import matplotlib.pyplot as plt



# Selecting locationAbbr and topic to analyse the trend
x_column = "LocationAbbr"
y_column = "Topic"

# Creating  scatter plot of the two columns
plt.scatter(df[x_column], df[y_column], alpha=0.7)

# Adding labels to the axes
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.xticks(rotation = 100, fontsize=8)

# Add a title to the plot
plt.title("Scatter Plot of {} vs. {}".format(x_column, y_column))

# Show the plot
plt.show()

# %%
# your answer here

# %%
# your answer here

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Question 8
# Since we have location information in this dataset, show a suitable geo spatial display of diseases. Pick any that interests you.

# %%
# your answer here

# %%
# %pip install plotly

# %%
import pandas as pd
# %pip install plotly
import plotly.express as px


URL = pd.read_csv('https://storage.googleapis.com/assignment-data/U.S._Chronic_Disease_Indicators__CDI_.csv')
import pandas as pd
import plotly.express as px


Diabetes_df = df[
    (df['YearStart'] == 2014)& 
    (df['YearEnd'] == 2018) & 
    (~df['LocationAbbr'].isin(['AZ','MI', 'AR', 'MD'])) & 
    (df['Question'] == 'Diabetes (all sites combined), Data') & 
    (df['DataValueType'] == 'Average Annual Number') & 
    (df['StratificationCategoryID1'] == 'OVERALL')
]

Diabetes_df['DataValue'] = pd.to_numeric(Diabetes_df['DataValue'], errors='coerce')

fig = px.choropleth(
    Diabetes_df,
    locations="LocationAbbr",  
    locationmode="USA-states",
    color="DataValue",  
    scope="usa",  
    labels={"DataValue": "Average Annual Number", "LocationAbbr": "State"},
    title="Diabetes (all sites combined), incidence (2014-2018)"
)

fig.show()
# Out:
# Requirement already satisfied: plotly in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/SwathiB/anaconda3/lib/python3.11/site-packages (from plotly) (8.2.2)
# Note: you may need to restart the kernel to use updated packages.
# /var/folders/7w/dpsqt_c97m51kpcdctgblhtw0000gq/T/ipykernel_31389/556696697.py:6: DtypeWarning:
#
# Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
# %pip install folium

# %%
pip install geopandas

# %%
# %pip install cairo

# %%
# %pip install seaborn --upgrade

# %% [markdown]
# <!-- END QUESTION -->

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Upload this .zip file to Gradescope for grading.

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(pdf=False)
